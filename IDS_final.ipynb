# %%
import pandas as pd

# %%
df_2017 = pd.read_csv('MERGED2017_18_PP.csv', low_memory = False)
df_2017
# Out:
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 0                              Alabama A & M University           Normal
# 1                   University of Alabama at Birmingham       Birmingham
# 2                                    Amridge University       Montgomery
# 3                   University of Alabama in Huntsville       Huntsville
# 4                              Alabama State University       Montgomery
# ...                                                 ...              ...
# ...

# %% [markdown]
# Drop columns which have all NaN values

# %%
df_2017 = df_2017.dropna(axis=1, how='all')

# %%
df_2017.describe()
# Out:
#              UNITID         OPEID        OPEID6      SCH_DEG         MAIN  \
# count  7.112000e+03  7.112000e+03   7112.000000  6980.000000  7112.000000
# mean   1.867121e+06  1.866750e+06  16755.217660     1.923209     0.767717
# std    6.958737e+06  3.315240e+06  14589.294487     0.898395     0.422319
# min    1.006540e+05  1.002000e+05   1002.000000     1.000000     0.000000
# 25%    1.740728e+05  3.229750e+05   3224.750000     1.000000     1.000000
# 50%    2.289995e+05  1.056050e+06  10542.000000     2.000000     1.000000
# 75%    4.506005e+05  3.025825e+06  30106.000000     3.000000     1.000000
# max    4.900540e+07  8.209884e+07  42698.000000     3.000000     1.000000
#
#          NUMBRANCH      PREDDEG      HIGHDEG      CONTROL      ST_FIPS  ...  \
# count  7112.000000  7112.000000  7112.000000  7112.000000  7112.000000  ...
# mean      3.883155     1.834364     2.233830     2.129218    29.103487  ...
# ...

# %% [markdown]
# Limit to columns which have some arbitrary amount of Nulls (which can reasonably be handled) - discuss as a group
# I think it might be interesting to use the tool mentioned in class today so we don't have to manually do these things

# %%
nones = df_2017.isna().sum(axis = 0)
# size of all columns after removing first set
print(len(zeros.index.tolist()))
# size where we're enforcing the amount of NAs
print(len(nones[nones<500].index.tolist()))
print(len(nones[nones<250].index.tolist()))
print(len(nones[nones<140].index.tolist()))
print(len(nones[nones<135].index.tolist()))
print(len(nones[nones<130].index.tolist()))
# Out:
# 1689
# 1365
# 1126
# 1126
# 1096
# 115

# %% [markdown]
# Can restrict columns to the ones we want to deal with. For now <130 to make it easy to visually inspect

# %%
# limited_df = df_2020[nones[nones<140].index.tolist()]

# %%
# limited_df.columns.tolist()

# %%
privacy_suppressed = limited_df.isin(["PrivacySuppressed"]).sum(axis = 0)
pd.DataFrame(privacy_suppressed[privacy_suppressed<3000]) # arbitrary - roughly half of the original schools listed
# Out:
#                             0
# UNITID                      0
# OPEID                       0
# OPEID6                      0
# INSTNM                      0
# CITY                        0
# ...                       ...
# BBRR1_FED_UGCOMP_N       1587
# BBRR1_FED_UGCOMP_FBR     2739
# BBRR1_FED_UGCOMP_NOPROG  2587
# BBRR1_FED_UGNOCOMP_N     2944
# BBRR1_PP_UG_N            2923
#
# [178 rows x 1 columns]

# %%
privacy_suppressed[privacy_suppressed<3000].index.tolist()
# Out:
# ['UNITID',
#  'OPEID',
#  'OPEID6',
#  'INSTNM',
#  'CITY',
#  'STABBR',
#  'ZIP',
#  'SCH_DEG',
#  'MAIN',
#  'NUMBRANCH',
#  'PREDDEG',
#  'HIGHDEG',
#  'CONTROL',
#  'ST_FIPS',
#  'REGION',
#  'COMP_ORIG_YR2_RT',
#  'WDRAW_ORIG_YR2_RT',
#  'LO_INC_COMP_ORIG_YR2_RT',
#  'LO_INC_WDRAW_ORIG_YR2_RT',
#  'DEP_COMP_ORIG_YR2_RT',
#  'IND_COMP_ORIG_YR2_RT',
#  'COMP_ORIG_YR3_RT',
#  'WDRAW_ORIG_YR3_RT',
#  'WDRAW_2YR_TRANS_YR3_RT',
#  'LO_INC_COMP_ORIG_YR3_RT',
#  'LO_INC_WDRAW_ORIG_YR3_RT',
#  'DEP_COMP_ORIG_YR3_RT',
#  'IND_COMP_ORIG_YR3_RT',
#  'FEMALE_COMP_ORIG_YR3_RT',
#  'MALE_COMP_ORIG_YR3_RT',
#  'FIRSTGEN_COMP_ORIG_YR3_RT',
#  'NOT1STGEN_COMP_ORIG_YR3_RT',
#  'COMP_ORIG_YR4_RT',
#  'WDRAW_ORIG_YR4_RT',
#  'WDRAW_2YR_TRANS_YR4_RT',
#  'LO_INC_COMP_ORIG_YR4_RT',
#  'LO_INC_WDRAW_ORIG_YR4_RT',
#  'DEP_COMP_ORIG_YR4_RT',
#  'IND_COMP_ORIG_YR4_RT',
#  'FEMALE_COMP_ORIG_YR4_RT',
#  'MALE_COMP_ORIG_YR4_RT',
#  'FIRSTGEN_COMP_ORIG_YR4_RT',
#  'NOT1STGEN_COMP_ORIG_YR4_RT',
# ...

# %% [markdown]
# Maybe it's best to search for schools with the lowest values of NaN and PrivacySuppressed values? Or to limit to schools we're interested in? If this is the case, this dataset may be problematic.
